# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("O:\Payroll Services\Automation\Fung\VSC\Others\github-stack_overflow_developer_survey\developer_survey_2019\survey_results_public.csv")
df.head()

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# 1. How many respondent code as hobby?

# %%
num_of_hobbyist = len(df[df.Hobbyist == 'Yes'])
total = len(df)
yes_pct = round(num_of_hobbyist / total * 100, 2)
print(f'There are {num_of_hobbyist} out of {total} identify themselve as hobbyist, around {yes_pct}%')
# Out:
# There are 71257 out of 88883 identify themselve as hobbyist, around 80.17%

# %% [markdown]
# 2. Which language have you worked with?

# %%
s  = df['LanguageWorkedWith'].str.split(';').apply(pd.Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'LanguageWorkedWith'
del df['LanguageWorkedWith']
df = df.join(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# o:\Payroll Services\Automation\Fung\VSC\Others\github-stack_overflow_developer_survey\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
new_df.columns = ['Respondent', 'LanguageWorkedWith']

# %%
new_df
# Out:
#        Respondent                                 LanguageWorkedWith
# 0               1                            [C++, HTML/CSS, Python]
# 1               2                                         [HTML/CSS]
# 2               3                          [C, C++, C#, Python, SQL]
# 3               4  [C++, HTML/CSS, Java, JavaScript, Python, SQL,...
# 4               5                                     [Java, R, SQL]
# ...           ...                                                ...
# 87563       88076                             [HTML/CSS, JavaScript]
# 87564       88182               [C#, HTML/CSS, JavaScript, PHP, SQL]
# 87565       88212          [Bash/Shell/PowerShell, C, HTML/CSS, SQL]
# 87566       88282                                   [C, Python, SQL]
# 87567       88863                                [C, C++, Other(s):]
#
# [87568 rows x 2 columns]
